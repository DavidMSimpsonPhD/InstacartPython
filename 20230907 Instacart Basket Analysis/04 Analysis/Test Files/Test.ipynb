# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#defining path
path = r'/Users/davidmsimpson/20230907 Instacart Basket Analysis'

# %%
# Import df_ords_prods_merged
df_ords_prods_mergedP = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged.pkl'))

# %%
df_ords_prods_mergedP.shape
# Out:
# (32434212, 19)

# %%
df_ords_prods_mergedP.describe()
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0_x      order_id       user_id  \
# count  3.243421e+07  3.243421e+07  3.243421e+07  3.243421e+07  3.243421e+07
# mean   1.709860e+06  1.709860e+06  1.709860e+06  1.710748e+06  1.029374e+05
# std    9.864638e+05  9.864638e+05  9.864638e+05  9.872996e+05  5.946649e+04
# min    0.000000e+00  0.000000e+00  0.000000e+00  2.000000e+00  1.000000e+00
# 25%    8.556130e+05  8.556130e+05  8.556130e+05  8.559450e+05  5.142000e+04
# 50%    1.709152e+06  1.709152e+06  1.709152e+06  1.711049e+06  1.026125e+05
# 75%    2.565947e+06  2.565947e+06  2.565947e+06  2.565510e+06  1.543910e+05
# max    3.421081e+06  3.421081e+06  3.421081e+06  3.421083e+06  2.062090e+05
#
#        order_number  order_day_of_week  order_hour_of_day  \
# count  3.243421e+07       3.243421e+07       3.243421e+07
# mean   1.714192e+01       2.738810e+00       1.342500e+01
# std    1.753489e+01       2.090047e+00       4.246351e+00
# ...

# %%
# Import df_ords_prods_merged
df_ords_prods_merged = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged.csv'), index_col = 0)

# %%
df_ords_prods_merged.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  2.305000e+07  2.305000e+07  2.305000e+07       2.305000e+07
# mean   1.710782e+06  1.029045e+05  1.747529e+01       2.716545e+00
# std    9.873360e+05  5.948380e+04  1.773738e+01       2.096289e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.558338e+05  5.133100e+04  5.000000e+00       1.000000e+00
# 50%    1.711149e+06  1.025360e+05  1.100000e+01       2.000000e+00
# 75%    2.565583e+06  1.543630e+05  2.400000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01       6.000000e+00
#
#        order_hour_of_day  days_since_prior_order  new_customer    product_id  \
# count       2.305000e+07            2.160716e+07  2.305000e+07  2.305000e+07
# mean        1.341040e+01            1.101424e+01  6.259618e-02  2.590875e+04
# std         4.246393e+00            8.722806e+00  2.422352e-01  1.398866e+04
# ...

# %%
df_ords_prods_merged.shape
# Out:
# (23050000, 20)

# %%
df_ords_prods_merged.head(15)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# ...

# %%
df_ords_prods_merged.tail(15)
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 23049985    527384    74472             2                  5
# 23049986   2134779    74472             3                  5
# 23049987   1141788    74498             2                  6
# 23049988   2995009    74498             3                  0
# 23049989   1566007    74498             4                  6
# 23049990   1261155    74498             6                  6
# 23049991   2738471    74498             7                  1
# 23049992    675573    74498            10                  5
# 23049993    803913    74565            16                  2
# 23049994   1346670    74565            20                  6
# 23049995   3336004    74565            22                  6
# 23049996   3269683    74565            24                  2
# 23049997   2531903    74565            26                  5
# 23049998   1657372    74565            28                  1
# ...

# %%
df_ords_prods_mergedP.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0             0   2539329        1             1
# 1             1             1             1   2398795        1             2
# 2             2             2             2    473747        1             3
# 3             3             3             3   2254736        1             4
# 4             4             4             4    431534        1             5
#
#    order_day_of_week  order_hour_of_day  days_since_prior_order  new_customer  \
# 0                  2                  8                     NaN          True
# 1                  3                  7                    15.0         False
# 2                  3                 12                    21.0         False
# 3                  4                  7                    29.0         False
# 4                  4                 15                    28.0         False
#
# ...

# %%
df_ords_prods_mergedP.drop(columns = ['Unnamed: 0.2'])
# Out:
#           Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0                    0             0   2539329        1             1
# 1                    1             1   2398795        1             2
# 2                    2             2    473747        1             3
# 3                    3             3   2254736        1             4
# 4                    4             4    431534        1             5
# ...                ...           ...       ...      ...           ...
# 32434207       3360493       3360493   1320836   202557            17
# 32434208       3360494       3360494     31526   202557            18
# 32434209       3376038       3376038    758936   203436             1
# 32434210       3376039       3376039   2745165   203436             2
# 32434211       3408036       3408036   3093936   205420             1
#
#           order_day_of_week  order_hour_of_day  days_since_prior_order  \
# ...

# %%
df_ords_prods_mergedP.drop(columns = ['Unnamed: 0.1','Unnamed: 0.2', 'Unnamed: 0_x', 'Unnamed: 0_y'])
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32434207   1320836   202557            17                  2
# 32434208     31526   202557            18                  5
# 32434209    758936   203436             1                  2
# 32434210   2745165   203436             2                  3
# 32434211   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                         8                     NaN          True         196
# ...

# %%
df_ords_prods_mergedP.tail(15)
# Out:
#           Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  \
# 32434197       3360480       3360480       3360480   1928449   202557
# 32434198       3360482       3360482       3360482   2222639   202557
# 32434199       3360484       3360484       3360484    339942   202557
# 32434200       3360485       3360485       3360485   2798193   202557
# 32434201       3360487       3360487       3360487   2391791   202557
# 32434202       3360488       3360488       3360488    576295   202557
# 32434203       3360489       3360489       3360489    960088   202557
# 32434204       3360490       3360490       3360490    343962   202557
# 32434205       3360491       3360491       3360491   2329472   202557
# 32434206       3360492       3360492       3360492    694731   202557
# 32434207       3360493       3360493       3360493   1320836   202557
# 32434208       3360494       3360494       3360494     31526   202557
# ...

# %%
# Import df_ords_prods_merged2
df_ords_prods_merged2 = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged2.csv'), index_col = 0)

# %%
df_ords_prods_merged2.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  2.305000e+07  2.305000e+07  2.305000e+07       2.305000e+07
# mean   1.710782e+06  1.029045e+05  1.747529e+01       2.716545e+00
# std    9.873360e+05  5.948380e+04  1.773738e+01       2.096289e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.558338e+05  5.133100e+04  5.000000e+00       1.000000e+00
# 50%    1.711149e+06  1.025360e+05  1.100000e+01       2.000000e+00
# 75%    2.565583e+06  1.543630e+05  2.400000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01       6.000000e+00
#
#        order_hour_of_day  days_since_prior_order  new_customer    product_id  \
# count       2.305000e+07            2.160716e+07  2.305000e+07  2.305000e+07
# mean        1.341040e+01            1.101424e+01  6.259618e-02  2.590875e+04
# std         4.246393e+00            8.722806e+00  2.422352e-01  1.398866e+04
# ...

# %%
df_ords_prods_merged2.head(15)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# ...
