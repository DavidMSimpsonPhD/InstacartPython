# %% [markdown]
# ### Contents
# #### Importing libraries
# #### Importing data sets
# #### Merging dataframes
# #### Using merge flag

# %% [markdown]
# ## Importing Libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Importing Dataframes

# %%
path = r'/Users/davidmsimpson/20230907 Instacart Basket Analysis'

# %%
# Import df_orders_products_combined
df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0             0           0   2539329        1             1
# 1             0             0           0   2539329        1             1
# 2             0             0           0   2539329        1             1
# 3             0             0           0   2539329        1             1
# 4             0             0           0   2539329        1             1
#
#    order_day_of_week  order_hour_of_day  days_since_prior_order  new_customer  \
# 0                  2                  8                     NaN          True
# 1                  2                  8                     NaN          True
# 2                  2                  8                     NaN          True
# 3                  2                  8                     NaN          True
# 4                  2                  8                     NaN          True
#
# ...

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 14)

# %%
# Import df_products_checked
df_products_checked = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_products_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# ## Merging dataframes

# %%
# Merging df_orders_products_combined and df_products_checked 
df_total_products_merged = df_orders_products_combined.merge(df_products_checked, on = 'product_id')

# %%
df_total_products_merged.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0             0   2539329        1             1
# 1             1             1             1   2398795        1             2
# 2             2             2             2    473747        1             3
# 3             3             3             3   2254736        1             4
# 4             4             4             4    431534        1             5
#
#    order_day_of_week  order_hour_of_day  days_since_prior_order  new_customer  \
# 0                  2                  8                     NaN          True
# 1                  3                  7                    15.0         False
# 2                  3                 12                    21.0         False
# 3                  4                  7                    29.0         False
# 4                  4                 15                    28.0         False
#
# ...

# %%
# Using the merge flag
df_total_products_merged['_merge'].value_counts()
# Out:
# _merge
# both          32434212
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Export data to pkl

df_total_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'total_products_merged.pkl'))
